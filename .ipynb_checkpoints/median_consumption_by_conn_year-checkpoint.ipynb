# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
import seaborn as sns

# %%
# %%time
# customer payments
payts_datafile = '/mnt/nfs/work1/jtaneja/jmugyenyi/REG_consumption_data/smoothed_payments_06142021.pck'
payts_df = pd.read_pickle(payts_datafile)
payts_df['trans_period'] = pd.to_datetime(payts_df[['year','month']].assign(day= lambda x: x['month'].apply(
    lambda y: 31 if y in    [1,3,5,7,8,10,12] else (30 if y in [4,6,9,11] else (28 if y==2 else np.nan)))))
# Out:
# CPU times: user 16 s, sys: 6.15 s, total: 22.2 s
# Wall time: 22.2 s

# %%
# %%time
low_customer_tariffs = {'date': ['01/07/2012', '31/08/2015', '01/09/2015', '31/12/2016', '01/01/2017', '13/08/2018', '20/01/2020'],
                        'price (rwf)': [134,134, 182,182, 89, 89, 89]}
low_tarrif_df = pd.DataFrame(data=low_customer_tariffs)
low_tarrif_df['date'] = pd.to_datetime(low_tarrif_df['date'], format='%d/%m/%Y')
low_tarrif_df.set_index(['date'],inplace=True)

high_customer_tariffs = {'date': ['01/07/2012', '31/08/2015', '01/09/2015', '31/12/2016', '01/01/2017', '13/08/2018', '20/01/2020'],
                        'price (rwf)': [134, 134, 182, 182, 189, 189, 189]}
high_tarrif_df = pd.DataFrame(data=high_customer_tariffs)
high_tarrif_df['date'] = pd.to_datetime(high_tarrif_df['date'], format='%d/%m/%Y')
high_tarrif_df.set_index(['date'],inplace=True)

consumption_datafile = '/mnt/nfs/work1/jtaneja/jmugyenyi/REG_consumption_data/smoothed_folder/merged_smoothed_monthly_by_meternumber_consumerid_march032021.pck'
df = pd.read_pickle(consumption_datafile)
df['trans_period'] = pd.to_datetime(df[['year','month']].assign(day= lambda x: x['month'].apply(
    lambda y: 31 if y in    [1,3,5,7,8,10,12] else (30 if y in [4,6,9,11] else (28 if y==2 else np.nan)))))
meta_datafile = '/mnt/nfs/work1/jtaneja/jmugyenyi/REG_consumption_data/metadata_folder/REG_metadata_March_3_2021.pck'
meta_df = pd.read_pickle(meta_datafile)
meta_df['meter_serial_number_consumer_id'] = meta_df['meter_serial_number'].astype(str) +'_'+ meta_df['consumer_id']
meta_df['installation_year'] = meta_df.installation_date.dt.year
b = ['10. Residential', '2. T1 Tx FC1 AR STS']
res_meta = meta_df[meta_df.vending_category_name.apply(lambda y: any(x in b for x in y))]
# Out:
# CPU times: user 25.4 s, sys: 7.13 s, total: 32.5 s
# Wall time: 32.5 s

# %%
df
# Out:
#                       meter_serial_number_consumer_id  meter_serial_number  \
# 0         4226691618_20130515 102321.279 0002030 2194           4226691618
# 1         4226691618_20130515 102321.279 0002030 2194           4226691618
# 2         4226691618_20130515 102321.279 0002030 2194           4226691618
# 3         4226691618_20130515 102321.279 0002030 2194           4226691618
# 4         4226691618_20130515 102321.279 0002030 2194           4226691618
# ...                                               ...                  ...
# 32670273  7067107784_20140103 120315.782 0002010 4018           7067107784
# 32670274  7067107784_20140103 120315.782 0002010 4018           7067107784
# 32670275  7067107784_20140103 120315.782 0002010 4018           7067107784
# 32670276  7067107784_20140103 120315.782 0002010 4018           7067107784
# 32670277  7067107784_20140103 120315.782 0002010 4018           7067107784
#
# ...

# %% [markdown]
# # Low consumers

# %%
# %%time
## quartiles for low consumption

# lists
quartiles = [0.25, 0.50, 0.75]          # inter-quartile range
lower_quat_list=[]                 # lower quartile kWhs
median_list=[]                     # median kWhs
upper_quat_list=[]                 # upper quartile kWhs

customers_per_conn_year =[]             # number of customers per installation year
customer_per_month_per_conn_year = {}   # number of customers per installation year per transaction month
years_list = [2010,2011,2012,
              2013,2014,2015,2016,2017,2018,2019] # installation years

combined_low_df = pd.DataFrame()

for year in years_list:
    if year==2010:
        meta_year_filter = res_meta[res_meta.installation_year <= 2010] # filter installation years b4 and equal to 2010
    else:
        meta_year_filter = res_meta[res_meta.installation_year == year] # filter based off installation year
        
    df_by_year = df[df.meter_serial_number_consumer_id.isin(
        meta_year_filter.meter_serial_number_consumer_id)] # create subset dataframe with single year of installation
    
    x = df_by_year.groupby(['meter_serial_number_consumer_id','year']
                          ).mean()['kWhs'].reset_index() # compute average consumption per year
    if year <=2013:
        # average consumption in initial years of connection
        low_consumers = x[(x.year==2013) & (x.kWhs <10)].meter_serial_number_consumer_id.unique().tolist()
    else:  
        # average consumption in initial years of connection
        low_consumers = x[(x.year==year) & (x.kWhs <10)].meter_serial_number_consumer_id.unique().tolist()
        
    # create subset of low consumption customers
    low_df_by_year = df[df.meter_serial_number_consumer_id.isin(low_consumers)]
    
    # create subset with payments
    y = low_df_by_year[['meter_serial_number_consumer_id','kWhs','trans_period']]
    result = pd.merge(y, payts_df[['meter_serial_number_consumer_id','amounts','trans_period']], 
                  on=['meter_serial_number_consumer_id','trans_period'],how='inner')
    
    # store all low customer transactions in single dataframe    
    combined_low_df = pd.concat([combined_low_df, result])
    
    # count number of low consumers per transaction period(monthly)
    customer_per_month_per_conn_year[year] = low_df_by_year.groupby(
        ['trans_period'])['meter_serial_number_consumer_id'].count()
    
    # compute quartile stats for consumption
    quartiles_df = result.groupby(['trans_period']).quantile([0.25,0.5,0.75])[['kWhs','amounts']]
    temp = quartiles_df.reset_index().rename(columns={'level_1':'quartiles'})
    temp.loc[ (temp.trans_period > '2012-07-01') & (temp.trans_period <= '2015-08-31'), 'tariff'] = 134
    temp.loc[ (temp.trans_period > '2015-08-31') & (temp.trans_period <= '2016-12-31'), 'tariff'] = 182
    temp.loc[ (temp.trans_period > '2016-12-31'), 'tariff'] = 89
    temp['payment'] = temp['kWhs'] * temp['tariff']
    
    
    for quart in quartiles:
        tmp = temp[temp.quartiles==quart]
        tmp = tmp.set_index(['trans_period'])
        tmp = tmp.drop(['quartiles'],axis=1)
 
        
        if quart==0.25:
            lower_quat_list.append(tmp)

        elif quart==0.50:
            median_list.append(tmp)

        elif quart==0.75:
            upper_quat_list.append(tmp)

    
    cust_count = low_df_by_year.meter_serial_number_consumer_id.nunique()
    if year==2010:
        customers_per_conn_year.append(f"{year} & before : {cust_count} customers")
    else:
        customers_per_conn_year.append(f"{year} : {cust_count} customers")
#     break
# Out:
# CPU times: user 3min 26s, sys: 44.6 s, total: 4min 10s
# Wall time: 4min 10s

# %% [markdown]
# ### Monthly count for low consumers

# %%
# %%time
# lower consumer monthly count
fig, ax = plt.subplots(figsize=(15,7))
colors = ['cyan', 'green', 'brown', 'blue', 'black', 'gray','orange','olive','tab:purple','yellow']
for k, v in (customer_per_month_per_conn_year.items()):
    ax.plot(v,label=k, )
    ax.legend()
ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('number of customers', fontsize=16)
ax.set_title(f'Number of low consuming customers by connection year at the end of @ transaction period', fontsize=20)
plt.show()
# Out:
# CPU times: user 283 ms, sys: 18.7 ms, total: 302 ms
# Wall time: 297 ms

# %% [markdown]
# ### Upper quartile, median and lower quartile stats

# %%
# %%time
# quartiles stats low consumption
fig, ax1 = plt.subplots(figsize=(15,7))
colors = ['cyan', 'green', 'brown', 'blue', 'black', 'gray','orange','olive','tab:purple','yellow']

var_of_interest = 'payment'
smoothed = True
key = 'median'

quart_stats = {
    'upper_quartile':upper_quat_list,
    'median':median_list,
    'lower_quartile':lower_quat_list
}


for n,i in enumerate(quart_stats[key]):
    if smoothed:
        if var_of_interest == 'kWh':
            ax1.plot(i.kWhs.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'amounts':
            ax1.plot(i.amounts.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'payment':
            ax1.plot(i.payment.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
    else:
        if var_of_interest == 'kWh':
            ax1.plot(i.kWhs,label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'amounts':
            ax1.plot(i.amounts,label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'payment':
            ax1.plot(i.payment,label=customers_per_conn_year[n], color=colors[n])
    ax1.legend()
    
    
ax1.set_xlabel('Years', fontsize=16)
ax1.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 5, 1)])
if var_of_interest == 'kWh':
    ax1.set_ylabel('kWh', fontsize=16)
    ax1.set_title(f'{key} consumption for low consumers by connection year', fontsize=20)
else:
    ax1.set_ylabel('rwf', fontsize=16)
    ax1.set_title(f'{key} payments for low consumers by connection year', fontsize=20)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff', color=color, fontsize=16)  # we already handled the x-label with ax1
ax2.plot(low_tarrif_df,'x', color=color, ls='--', label='tariff')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend()

# rotates labels 
plt.setp( ax1.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 
plt.show()
# Out:
# CPU times: user 388 ms, sys: 7.08 ms, total: 395 ms
# Wall time: 392 ms

# %% [markdown]
# # High consumption

# %%
# %%time
# quartiles for high consumption

# lists
quartiles = [0.25, 0.50, 0.75]          # inter-quartile range
lower_quat_list=[]                 # lower quartile kWhs
median_list=[]                     # median kWhs
upper_quat_list=[]                 # upper quartile kWhs

customers_per_conn_year =[]             # number of customers per installation year
customer_per_month_per_conn_year = {}   # number of customers per installation year per transaction month
years_list = [2010,2011,2012,
              2013,2014,2015,2016,2017,2018,2019] # installation years

combined_high_df = pd.DataFrame()


for year in years_list:
    if year==2010:
        meta_year_filter = res_meta[res_meta.installation_year <= 2010]
    else:
        meta_year_filter = res_meta[res_meta.installation_year == year]
    df_by_year = df[df.meter_serial_number_consumer_id.isin(meta_year_filter.meter_serial_number_consumer_id)]
    x = df_by_year.groupby(['meter_serial_number_consumer_id','year']).mean()['kWhs'].reset_index()
    if year <=2013:
        high_consumers = x[(x.year==2013) & (x.kWhs >50)].meter_serial_number_consumer_id.unique().tolist()
    else:     
        high_consumers = x[(x.year==year) & (x.kWhs >50)].meter_serial_number_consumer_id.unique().tolist()
        
    # create subset of low consumption customers
    high_df_by_year = df[df.meter_serial_number_consumer_id.isin(high_consumers)]
    
    # create subset with payments
    y = high_df_by_year[['meter_serial_number_consumer_id','kWhs','trans_period']]
    result = pd.merge(y, payts_df[['meter_serial_number_consumer_id','amounts','trans_period']], 
                  on=['meter_serial_number_consumer_id','trans_period'],how='inner')
    
    # store all low customer transactions in single dataframe    
    combined_high_df = pd.concat([combined_high_df, result])
        
    # count number of low consumers per transaction period(monthly)
    customer_per_month_per_conn_year[year] = high_df_by_year.groupby(
        ['trans_period'])['meter_serial_number_consumer_id'].count()
    
    high_df_by_year = df_by_year[df_by_year.meter_serial_number_consumer_id.isin(high_consumers)]
    quartile_cons = high_df_by_year.groupby(['trans_period']).quantile([0.25,0.5,0.75])['kWhs']
    temp = quartile_cons.reset_index().rename(columns={'level_1':'quartiles'})
    temp.loc[ (temp.trans_period > '2012-07-01') & (temp.trans_period <= '2015-08-31'), 'tariff'] = 134
    temp.loc[ (temp.trans_period > '2015-08-31') & (temp.trans_period <= '2016-12-31'), 'tariff'] = 182
    temp.loc[ (temp.trans_period > '2016-12-31')& (temp.trans_period <= '2018-07-30'), 'tariff'] = 189
    temp.loc[ (temp.trans_period > '2018-07-30'), 'tariff'] = 210
    temp['payment'] = temp['kWhs'] * temp['tariff']
    
    
    for quart in quartiles:
        tmp = temp[temp.quartiles==quart]
        tmp = tmp.set_index(['trans_period'])
        tmp = tmp.drop(['quartiles'],axis=1)
 
        
        if quart==0.25:
            lower_quat_list.append(tmp)

        elif quart==0.50:
            median_list.append(tmp)

        elif quart==0.75:
            upper_quat_list.append(tmp)

    
    cust_count = high_df_by_year.meter_serial_number_consumer_id.nunique()
    if year==2010:
        customers_per_conn_year.append(f"{year} & before : {cust_count} customers")
    else:
        customers_per_conn_year.append(f"{year} : {cust_count} customers")
#     break
# Out:
# CPU times: user 2min 58s, sys: 42.4 s, total: 3min 40s
# Wall time: 3min 40s

# %% [markdown]
# ### Monthly count for high consumers

# %%
customers_per_conn_year # why so many high consumers before 2010
# Out:
# ['2010 & before : 45661 customers',
#  '2011 : 6871 customers',
#  '2012 : 3847 customers',
#  '2013 : 3283 customers',
#  '2014 : 2436 customers',
#  '2015 : 1989 customers',
#  '2016 : 1577 customers',
#  '2017 : 1453 customers',
#  '2018 : 1381 customers',
#  '2019 : 1452 customers']

# %%
customer_per_month_per_conn_year
# Out:
# {2010: trans_period
#  2012-10-31    39923
#  2012-11-30    41350
#  2012-12-31    41708
#  2013-01-31    42133
#  2013-02-28    42064
#                ...
#  2020-04-30    29546
#  2020-05-31    13205
#  2020-06-30       69
#  2020-07-31       13
#  2020-08-31        3
#  Name: meter_serial_number_consumer_id, Length: 95, dtype: int64,
#  2011: trans_period
#  2012-10-31    5803
#  2012-11-30    6073
#  2012-12-31    6113
#  2013-01-31    6184
#  2013-02-28    6175
#                ...
#  2020-03-31    4385
#  2020-04-30    4047
#  2020-05-31    1692
#  2020-06-30       8
#  2020-07-31       4
#  Name: meter_serial_number_consumer_id, Length: 94, dtype: int64,
#  2012: trans_period
#  2012-10-31    2590
#  2012-11-30    2888
#  2012-12-31    3141
#  2013-01-31    3275
#  2013-02-28    3247
#                ...
#  2020-02-28    2267
#  2020-03-31    2260
#  2020-04-30    2055
#  2020-05-31     863
#  2020-06-30       4
# ...

# %%
# %%time
# Upper consumer monthly count
fig, ax = plt.subplots(figsize=(15,7))
colors = ['cyan', 'green', 'brown', 'blue', 'black', 'gray','orange','olive','tab:purple','yellow']
for k, v in (customer_per_month_per_conn_year.items()):
    ax.plot(v,label=k, )
    ax.legend()
ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('number of customers', fontsize=16)
ax.set_title(f'Number of high consuming customers by connection year at the end of @ transaction period', fontsize=20)
plt.show()
# Out:
# CPU times: user 276 ms, sys: 13.8 ms, total: 290 ms
# Wall time: 287 ms

# %% [markdown]
# ### Upper quartile, median and lower quartile stats

# %%
# %%time
# quartiles stats high consumption
fig, ax1 = plt.subplots(figsize=(15,7))
colors = ['cyan', 'green', 'brown', 'blue', 'black', 'gray','orange','olive','tab:purple','yellow']

var_of_interest = 'kWh'
smoothed = True
key = 'lower_quartile'

quart_stats = {
    'upper_quartile':upper_quat_list,
    'median':median_list,
    'lower_quartile':lower_quat_list
}


for n,i in enumerate(quart_stats[key]):
    if smoothed:
        if var_of_interest == 'kWh':
            ax1.plot(i.kWhs.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'amounts':
            ax1.plot(i.amounts.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'payment':
            ax1.plot(i.payment.rolling(3, min_periods=1).mean(),label=customers_per_conn_year[n], color=colors[n])
    else:
        if var_of_interest == 'kWh':
            ax1.plot(i.kWhs,label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'amounts':
            ax1.plot(i.amounts,label=customers_per_conn_year[n], color=colors[n])
        elif var_of_interest == 'payment':
            ax1.plot(i.payment,label=customers_per_conn_year[n], color=colors[n])
    ax1.legend()
    
    
ax1.set_xlabel('Years', fontsize=16)
ax1.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 5, 1)])
if var_of_interest == 'kWh':
    ax1.set_ylabel('kWh', fontsize=16)
    ax1.set_title(f'{key} consumption for low consumers by connection year', fontsize=20)
    if key == 'lower_quartile':
        ax1.set_ylim([20,110])
    elif key == 'median':
        ax1.set_ylim([20,110])
    elif key == 'upper_quartile':
        ax1.set_ylim([70,200])
else:
    ax1.set_ylabel('rwf', fontsize=16)
    ax1.set_title(f'{key} payments for low consumers by connection year', fontsize=20)
    if key == 'lower_quartile':
        ax1.set_ylim([4000,13000])
    elif key == 'median':
        ax1.set_ylim([6000,20000])
    elif key == 'upper_quartile':
        ax1.set_ylim([10000,33000])
    


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff', color=color, fontsize=16)  # we already handled the x-label with ax1
ax2.plot(high_tarrif_df,'x', color=color, ls='--', label='tariff')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend()

# rotates labels 
plt.setp( ax1.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 
plt.show()
# Out:
# CPU times: user 482 ms, sys: 7.92 ms, total: 490 ms
# Wall time: 487 ms

# %% [markdown]
# # REVENUES

# %% [markdown]
# ### Revenues pre and post tariffs

# %% [markdown]
# #### All customers combined

# %%
# %%time
# select residential customers
res_payts_df =  payts_df[payts_df.meter_serial_number_consumer_id.isin(res_meta.meter_serial_number_consumer_id)]

# groupby by monthly payments then compute the total payments each month
payt_monthly_sums = res_payts_df.groupby(['trans_period'])['amounts'].sum()

# groupby by monthly payments then compute the total payments each month
payt_monthly_customer_count = res_payts_df.groupby(['trans_period'])['meter_serial_number_consumer_id'].count()

# revenue per residential customer
rev_per_cust = payt_monthly_sums.divide(payt_monthly_customer_count, fill_value=0)
# Out:
# CPU times: user 5.64 s, sys: 2.29 s, total: 7.93 s
# Wall time: 7.98 s

# %%
# %%time

from matplotlib.ticker import FuncFormatter
def billions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fB' % (x * 1e-9)


formatter = FuncFormatter(billions)



# total REG monthly revenues from residential customers
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(payt_monthly_sums)


ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in billions  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues for all residential customers', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.set_ylim([1000000000,3000000000])
ax.yaxis.set_major_formatter(formatter)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax1
ax2.plot(low_tarrif_df,'x', color=color, ls='--', label='tariff for low consumers')
ax2.plot(high_tarrif_df,'x', color='tab:green', ls='--', label='tariff for high consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 281 ms, sys: 5.14 ms, total: 286 ms
# Wall time: 283 ms

# %%
# %%time

# number of monthly customers
fig, ax = plt.subplots(figsize=(15,7))
color = 'tab:blue'
ax.plot(payt_monthly_sums, label='revenue in billions', color=color)

ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in billions  (rwf)',color=color, fontsize=16)
ax.set_title(f'Monthly REG revenues & customer growth', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.tick_params(axis='y', labelcolor=color)
ax.set_ylim([1000000000,3000000000])
ax.yaxis.set_major_formatter(formatter)
# ax.legend(loc=0)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel('Number of customers', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(payt_monthly_customer_count, color=color, label='count of residential customers @ month')
ax2.tick_params(axis='y', labelcolor=color)
# ax2.legend(loc=0)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 271 ms, sys: 4.11 ms, total: 275 ms
# Wall time: 273 ms

# %%
# %%time

# Revenues per customer per month
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(rev_per_cust)

ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue per customer  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues per customer (Residential)', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.set_ylim([4000,10000])

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(low_tarrif_df,'x', color=color, ls='--', label='tariff for low consumers')
ax2.plot(high_tarrif_df,'x', color='tab:green', ls='--', label='tariff for high consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 276 ms, sys: 5.7 ms, total: 282 ms
# Wall time: 279 ms

# %% [markdown]
# ### Low consumers revenue

# %%
# %%time
# select low residential customers
low_res_payts_df =  payts_df[payts_df.meter_serial_number_consumer_id.isin(combined_low_df.meter_serial_number_consumer_id)]

# groupby by monthly payments then compute the total payments each month
low_payt_monthly_sums = low_res_payts_df.groupby(['trans_period'])['amounts'].sum()

# groupby by monthly payments then compute the total payments each month
low_payt_monthly_customer_count = low_res_payts_df.groupby(['trans_period'])['meter_serial_number_consumer_id'].count()

# revenue per low residential customer
low_rev_per_cust = low_payt_monthly_sums.divide(payt_monthly_customer_count, fill_value=0)
# Out:
# CPU times: user 2.26 s, sys: 917 ms, total: 3.17 s
# Wall time: 3.16 s

# %%
# %%time

from matplotlib.ticker import FuncFormatter
def billions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fB' % (x * 1e-9)


formatter = FuncFormatter(billions)



# total REG monthly revenues from residential customers
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(low_payt_monthly_sums)

# ax.yaxis.set_major_formatter(formatter)
ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in hundreds of millions  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues for low consumption residential customers', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax1
ax2.plot(low_tarrif_df,'x', color=color, ls='--', label='tariff for low consumers')
# ax2.plot(high_tarrif_df,'x', color='tab:green', ls='--', label='tariff for high consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 267 ms, sys: 6.16 ms, total: 273 ms
# Wall time: 271 ms

# %%
# %%time

# number of monthly customers
fig, ax = plt.subplots(figsize=(15,7))
color = 'tab:blue'
ax.plot(low_payt_monthly_sums, label='revenue in billions', color=color)

ax.yaxis.set_major_formatter(formatter)
ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in billions  (rwf)',color=color, fontsize=16)
ax.set_title(f'Monthly REG revenues & customer growth for low consumers', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.tick_params(axis='y', labelcolor=color)
# ax.legend(loc=0)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel('Number of customers', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(low_payt_monthly_customer_count, color=color, label='count of residential customers @ month')
ax2.tick_params(axis='y', labelcolor=color)
# ax2.legend(loc=0)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 280 ms, sys: 8.54 ms, total: 289 ms
# Wall time: 285 ms

# %%
# %%time

# Revenues per customer per month
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(low_rev_per_cust)

ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue per customer  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues per customer (low consumption residential)', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(low_tarrif_df,'x', color=color, ls='--', label='tariff for low consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 251 ms, sys: 18.3 ms, total: 269 ms
# Wall time: 266 ms

# %% [markdown]
# ### High consumers revenue

# %%
# %%time
# select high residential customers
high_res_payts_df =  payts_df[payts_df.meter_serial_number_consumer_id.isin(combined_high_df.meter_serial_number_consumer_id)]

# groupby by monthly payments then compute the total payments each month
high_payt_monthly_sums = high_res_payts_df.groupby(['trans_period'])['amounts'].sum()

# groupby by monthly payments then compute the total payments each month
high_payt_monthly_customer_count = high_res_payts_df.groupby(['trans_period'])['meter_serial_number_consumer_id'].count()

# revenue per high residential customer
high_rev_per_cust = high_payt_monthly_sums.divide(payt_monthly_customer_count, fill_value=0)
# Out:
# CPU times: user 1.16 s, sys: 387 ms, total: 1.55 s
# Wall time: 1.54 s

# %%
# %%time

from matplotlib.ticker import FuncFormatter
def billions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fB' % (x * 1e-9)


formatter = FuncFormatter(billions)



# total REG monthly revenues from residential customers
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(high_payt_monthly_sums)


ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in billions  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues for high consumption residential customers', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.set_ylim([800000000,2000000000])
ax.yaxis.set_major_formatter(formatter)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:green'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax1
ax2.plot(high_tarrif_df,'x', color=color, ls='--', label='tariff for high consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 271 ms, sys: 6.25 ms, total: 277 ms
# Wall time: 275 ms

# %%
# %%time

# number of monthly customers
fig, ax = plt.subplots(figsize=(15,7))
color = 'tab:blue'
ax.plot(high_payt_monthly_sums, label='revenue in billions', color=color)

ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue in billions  (rwf)',color=color, fontsize=16)
ax.set_title(f'Monthly REG revenues & customer growth for high consumers', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.tick_params(axis='y', labelcolor=color)
ax.set_ylim([800000000,2000000000])
ax.yaxis.set_major_formatter(formatter)

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel('Number of customers', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(high_payt_monthly_customer_count, color=color, label='count of residential customers @ month')
ax2.tick_params(axis='y', labelcolor=color)
# ax2.legend(loc=0)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 254 ms, sys: 23 ms, total: 277 ms
# Wall time: 273 ms

# %%
# %%time

# Revenues per customer per month
fig, ax = plt.subplots(figsize=(15,7))

ax.plot(high_rev_per_cust)

ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('Revenue per customer  (rwf)', fontsize=16)
ax.set_title(f'Monthly REG revenues per customer (high consumption residential)', fontsize=20)
ax.set_xlim([datetime.date(2012, 1, 1), datetime.date(2020, 4, 1)])
ax.set_ylim([2000,7000])

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:green'
ax2.set_ylabel('tariff (rwf)', color=color, fontsize=16)  # we already handled the x-label with ax
ax2.plot(high_tarrif_df,'x', color=color, ls='--', label='tariff for high consumers')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc=3)

# rotates labels 
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45 , ha="left" , rotation_mode="anchor") 

plt.show()
# Out:
# CPU times: user 270 ms, sys: 3.44 ms, total: 274 ms
# Wall time: 271 ms

# %% [markdown]
# # Price Elasticity

# %%
from statsmodels.compat import lzip
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# %%time
consumption_model = ols("kWhs ~ amounts", data=combined_low_df).fit()
print(consumption_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   kWhs   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                 2.787e+08
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):               0.00
# Time:                        16:59:08   Log-Likelihood:            -2.7771e+07
# No. Observations:            10560814   AIC:                         5.554e+07
# Df Residuals:                10560812   BIC:                         5.554e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3037      0.001   2128.284      0.000       2.302       2.306
# ...

# %%
# %%time
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_partregress_grid(consumption_model, fig=fig)

# %%
# %%time
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_partregress_grid(consumption_model, fig=fig)
# Out:
# CPU times: user 56.9 s, sys: 1min 54s, total: 2min 50s
# Wall time: 8.13 s

# %% [markdown]
# ### low consumers

# %%
# %%time
count = 1
low_list = list(combined_low_df.meter_serial_number_consumer_id.unique())
step_size = 10000
length = (len(low_list)//step_size   + 1)* step_size
low_price_elasticity_df = pd.DataFrame()
for i in np.arange(0,length,step_size):
    start_idx = i
    stop_idx  = start_idx + step_size
    tmp_ids = low_list[start_idx:stop_idx]
    p = combined_low_df[combined_low_df.meter_serial_number_consumer_id.isin(tmp_ids)]
    q = p.groupby(['meter_serial_number_consumer_id'])[['kWhs','amounts']].diff()
    q.rename(columns={"kWhs": "kWhs_diff", "amounts": "amounts_diff"}, inplace=True)
    p = pd.concat([p,q],axis=1)
    low_price_elasticity_df = pd.concat([low_price_elasticity_df, p])
#     print(count)
#     count = count+1
low_price_elasticity_df['price_elasticity'] = low_price_elasticity_df['kWhs_diff']/low_price_elasticity_df['amounts_diff']
# Out:
# CPU times: user 1min 56s, sys: 21.9 s, total: 2min 18s
# Wall time: 2min 18s

# %%
low_price_elasticity_df
# Out:
#                      meter_serial_number_consumer_id       kWhs trans_period  \
# 0                                  4226691659_157450   2.036364   2013-01-31
# 1                                  4226691659_157450   7.163636   2014-01-31
# 2                                  4226691659_157450   9.763636   2015-01-31
# 3                                  4226691659_157450   4.563636   2016-01-31
# 4                                  4226691659_157450  13.454545   2018-01-31
# ...                                              ...        ...          ...
# 476757  14103238011_20191017 111322.437 0002400 1944   0.240000   2020-06-30
# 476758  14103238011_20191017 111322.437 0002400 1944   0.032000   2020-07-31
# 476759  14103238011_20191017 111322.437 0002400 1944   1.022857   2019-10-31
# 476760  14103238011_20191017 111322.437 0002400 1944   0.342857   2019-11-30
# 476761  14103238011_20191017 111322.437 0002400 1944   0.354286   2019-12-31
#
# ...

# %%
# %%time

medianprops = dict(linestyle='-', linewidth=4, color='k')

ax = low_price_elasticity_df.boxplot(column='price_elasticity',by='trans_period',medianprops=medianprops,
                                 figsize=(20,7),showfliers=False, grid=True, whis=False)
# plt.xticks(rotation=45)
labels = [item.get_text() for item in ax.get_xticklabels()]
ax.set_xticklabels([item[:10] for item in labels])
if len(labels) > 50:
    every_nth = 5
    for n, label in enumerate(ax.xaxis.get_ticklabels()):
        if n % every_nth != 0:
            label.set_visible(False)
for label in ax.get_xticklabels():
    label.set_rotation(90)
#     label.set_ha('right')
plt.xlabel('Transaction period',fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Customer Price Elasticity for low consumers', fontsize=20)
plt.show()
# Out:
# /home/jmugyenyi/.local/lib/python3.7/site-packages/numpy/core/_methods.py:151: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# CPU times: user 2.88 s, sys: 475 ms, total: 3.36 s
# Wall time: 3.36 s

# %% [markdown]
# ### High Consumers

# %%
# %%time
count = 1
high_list = list(combined_high_df.meter_serial_number_consumer_id.unique())
step_size = 1000
length = (len(high_list)//step_size   + 1)* step_size
high_price_elasticity_df = pd.DataFrame()
for i in np.arange(0,length,step_size):
    start_idx = i
    stop_idx  = start_idx + step_size
    tmp_ids = high_list[start_idx:stop_idx]
    p = combined_high_df[combined_high_df.meter_serial_number_consumer_id.isin(tmp_ids)]
    q = p.groupby(['meter_serial_number_consumer_id'])[['kWhs','amounts']].diff()
    q.rename(columns={"kWhs": "kWhs_diff", "amounts": "amounts_diff"}, inplace=True)
    p = pd.concat([p,q],axis=1)
    high_price_elasticity_df = pd.concat([high_price_elasticity_df, p])
#     print(count)
#     count = count+1
high_price_elasticity_df['price_elasticity'] = high_price_elasticity_df[
    'kWhs_diff']/high_price_elasticity_df['amounts_diff']
# Out:
# CPU times: user 37.3 s, sys: 12.2 s, total: 49.5 s
# Wall time: 49.5 s

# %%
# %%time

medianprops = dict(linestyle='-', linewidth=4, color='k')

ax = high_price_elasticity_df.boxplot(column='price_elasticity',by='trans_period',medianprops=medianprops,
                                 figsize=(20,7),showfliers=False, grid=True, whis=False)
# plt.xticks(rotation=45)
labels = [item.get_text() for item in ax.get_xticklabels()]
ax.set_xticklabels([item[:10] for item in labels])
if len(labels) > 50:
    every_nth = 5
    for n, label in enumerate(ax.xaxis.get_ticklabels()):
        if n % every_nth != 0:
            label.set_visible(False)
for label in ax.get_xticklabels():
    label.set_rotation(90)
#     label.set_ha('right')
plt.xlabel('Transaction period',fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.title('Customer Price Elasticity for high consumers', fontsize=20)
plt.show()
# Out:
# /home/jmugyenyi/.local/lib/python3.7/site-packages/numpy/core/_methods.py:151: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# CPU times: user 2.25 s, sys: 132 ms, total: 2.38 s
# Wall time: 2.38 s

# %%
length
# Out:
# 70000

# %%
high_price_elasticity_df
# Out:
#                     meter_serial_number_consumer_id        kWhs trans_period  \
# 0                                  4226692186_98449  107.450000   2014-01-31
# 1                                  4226692186_98449  146.100000   2015-01-31
# 2                                  4226692186_98449   62.600000   2016-01-31
# 3                                  4226692186_98449   84.200000   2017-01-31
# 4                                  4226692186_98449   99.966667   2018-01-31
# ...                                             ...         ...          ...
# 14925  94100291619_20190108 112634.086 0002011 8174   65.100000   2019-08-31
# 14926  94100291619_20190108 112634.086 0002011 8174   62.909091   2019-09-30
# 14927  94100291619_20190108 112634.086 0002011 8174   64.590909   2019-10-31
# 14928  94100291619_20190108 112634.086 0002011 8174   55.600000   2019-11-30
# 14929  94100291619_20190108 112634.086 0002011 8174   32.290909   2019-12-31
#
#             amounts  kWhs_diff  amounts_diff
# ...

# %%
high_price_elasticity_df
# Out:
#                     meter_serial_number_consumer_id        kWhs trans_period  \
# 0                                  4226692186_98449  107.450000   2014-01-31
# 1                                  4226692186_98449  146.100000   2015-01-31
# 2                                  4226692186_98449   62.600000   2016-01-31
# 3                                  4226692186_98449   84.200000   2017-01-31
# 4                                  4226692186_98449   99.966667   2018-01-31
# ...                                             ...         ...          ...
# 14925  94100291619_20190108 112634.086 0002011 8174   65.100000   2019-08-31
# 14926  94100291619_20190108 112634.086 0002011 8174   62.909091   2019-09-30
# 14927  94100291619_20190108 112634.086 0002011 8174   64.590909   2019-10-31
# 14928  94100291619_20190108 112634.086 0002011 8174   55.600000   2019-11-30
# 14929  94100291619_20190108 112634.086 0002011 8174   32.290909   2019-12-31
#
# ...
